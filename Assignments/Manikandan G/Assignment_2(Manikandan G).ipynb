# %% [markdown]
# # 1.Download the dataset:

# %% [markdown]
# The csv file is downloaded and uploaded to collab

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 2.Loading the dataset

# %%
df = pd.read_csv("/content/Churn_Modelling.csv")
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %% [markdown]
# # 3.Performing below visualiations

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 3.(i) Univariate Analysis

# %%
df.hist(column='Tenure',grid=False,edgecolor='black',color='pink')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb400227cd0>]],
#       dtype=object)

# %% [markdown]
# # 3.(ii) Bivariate Analysis

# %%
# sns.barplot(x='Exited',y='Tenure',data=df)
# sns.lineplot(df['Age'],df['Tenure'],color='maroon') 
sns.barplot(x="Age", y="Tenure", data=df).set_title('Age vs Tenure')
# Out:
# Text(0.5, 1.0, 'Age vs Tenure')

# %% [markdown]
# # 3.(iii) Multivariate Analysis

# %%
# sns.pairplot(df['Age'], df['Tenure'] , hue = 'Exited' )
sns.pairplot(df, hue ='Exited')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# # 4.Perform descriptive statistics on the dataset.

# %%
df.describe()
# Out:
#          RowNumber    CustomerId       Surname   CreditScore     Geography  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07   1507.774200    650.528800      0.746300
# std     2886.89568  7.193619e+04    846.204311     96.653299      0.827529
# min        1.00000  1.556570e+07      0.000000    350.000000      0.000000
# 25%     2500.75000  1.562853e+07    773.750000    584.000000      0.000000
# 50%     5000.50000  1.569074e+07   1542.000000    652.000000      0.000000
# 75%     7500.25000  1.575323e+07   2238.250000    718.000000      1.000000
# max    10000.00000  1.581569e+07   2931.000000    850.000000      2.000000
#
#              Gender           Age        Tenure        Balance  NumOfProducts  \
# count  10000.000000  10000.000000  10000.000000   10000.000000   10000.000000
# mean       0.545700     38.921800      4.857100   76485.889288       1.530200
# ...

# %% [markdown]
# # 5.Handle the Missing values.

# %%
# Method-1
df.info()
# Method-2
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  int64
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  int64
#  5   Gender           10000 non-null  int64
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(12)
# memory usage: 1.1 MB
# RowNumber          0
# CustomerId         0
# Surname            0
# ...

# %% [markdown]
# # 6.Find the outliers and replace the outliers

# %%
sns.boxplot(df['Tenure'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
outliers=np.where(df['Tenure']<7)
outliers
# Out:
# (array([   0,    1,    3, ..., 9995, 9998, 9999]),)

# %%
for i in outliers:
  df['Tenure'][i]=3 #replacing with previous value
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
sns.boxenplot(df['Tenure'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# #7. Check for Categorical columns and perform encoding.

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df["Surname"]=le.fit_transform(df["Surname"])
df['Geography']=le.fit_transform(df['Geography'])
df['Gender']=le.fit_transform(df['Gender'])

# %%
df.head()
# Out:
#    RowNumber  CustomerId  Surname  CreditScore  Geography  Gender  Age  \
# 0          1    15634602     1115          619          0       0   42
# 1          2    15647311     1177          608          2       0   41
# 2          3    15619304     2040          502          0       0   42
# 3          4    15701354      289          699          0       0   39
# 4          5    15737888     1822          850          2       0   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       3       0.00              1          1               1
# 1       3   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       3       0.00              2          0               0
# 4       3  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %% [markdown]
# #8. Split the data into dependent and independent variables.

# %%
x = df.iloc[:, 3:13]
y = df.iloc[:, 13]

# %% [markdown]
# #9. Scale the independent variables

# %%
x=x.drop(['Geography','Gender'],axis=1)
x
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       3       0.00              1          1
# 1             608   41       3   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       3       0.00              2          0
# 4             850   43       3  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       3       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       3  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary
# 0                  1        101348.88
# 1                  1        112542.58
# ...

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %% [markdown]
# #10. Split the data into training and testing

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
xtrain.shape,xtest.shape
# Out:
# ((7000, 8), (3000, 8))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
xtrain=sc.fit_transform(xtrain)
xtest=sc.fit_transform(xtest)
classifier=Sequential()
classifier.add(Dense(8,activation='relu'))
classifier.add(Dense(16,activation='relu'))
classifier.add(Dense(24,activation='relu'))
classifier.add(Dense(8,activation='relu'))
classifier.add(Dense(1,activation='linear'))
classifier.compile(optimizer = 'adam', loss = 'mse', metrics = ['accuracy'])
classifier.fit(xtrain,ytrain,batch_size=10,epochs=100)
# Out:
# Epoch 1/100
# 700/700 [==============================] - 5s 2ms/step - loss: 0.1459 - accuracy: 0.8093
# Epoch 2/100
# 700/700 [==============================] - 2s 2ms/step - loss: 0.1290 - accuracy: 0.8300
# Epoch 3/100
# 700/700 [==============================] - 2s 2ms/step - loss: 0.1195 - accuracy: 0.8460
# Epoch 4/100
# 700/700 [==============================] - 2s 2ms/step - loss: 0.1148 - accuracy: 0.8496
# Epoch 5/100
# 700/700 [==============================] - 2s 2ms/step - loss: 0.1132 - accuracy: 0.8519
# Epoch 6/100
# 700/700 [==============================] - 2s 3ms/step - loss: 0.1116 - accuracy: 0.8519
# Epoch 7/100
# 700/700 [==============================] - 2s 2ms/step - loss: 0.1102 - accuracy: 0.8546
# Epoch 8/100
# 700/700 [==============================] - 2s 2ms/step - loss: 0.1097 - accuracy: 0.8553
# Epoch 9/100
# 700/700 [==============================] - 2s 2ms/step - loss: 0.1088 - accuracy: 0.8569
# Epoch 10/100
# ...

# %%
ypred=classifier.predict(xtest)
from sklearn.metrics import r2_score
r2_score(ytest,ypred)*100
# Out:
# 31.313108078669337
